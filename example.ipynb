# %% [markdown]
# ## 配置环境
# ---
#
# 先根据README创建一个虚拟环境dassl，并配置好dassl，确保下面的命令`import dassl`有效

# %%
import dassl

# %% [markdown]
# ## 下载数据集
# ---
# 请根据[dataset.md](https://github.com/KaiyangZhou/CoOp/blob/main/DATASETS.md)下载数据集。目前仅支持`caltech101`
#
# 也可以直接通过下面的git命令下载整个项目，里面包含`caltech101`数据集

# %%
# !git clone https://github.com/attract666/ml_exam.git
# Out:
# Cloning into 'ml_exam'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 71 (delta 13), reused 35 (delta 12), pack-reused 34
# Receiving objects: 100% (71/71), 127.32 MiB | 39.62 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# !cat /content/ml_exam/101_ObjectCategories.tar.gz* | tar -zx
# !mkdir data
# !mkdir data/caltech-101
# !mv /content/101_ObjectCategories /content/data/caltech-101/101_ObjectCategories
# !mv /content/ml_exam/split_zhou_Caltech101.json /content/data/caltech-101/split_zhou_Caltech101.json

# %% [markdown]
# ## 运行脚本
# ---
#
# - 修改`ml_exam/scripts/main.sh`中的`DATA`为数据集路径，例如'/content/101_ObjectCategories'
# - 修改`ml_exam/scripts/main.sh`中的'your_work_path'

# %%
import os
os.chdir('/content/ml_exam/plot-coop/scripts/')

# %%
# !bash ./main.sh caltech101 4
# Out:
# Run this job and save the output to /content/ml_exam/plot-coop/output/OP_N4/caltech101/PLOT/rn50_1shots/nctx16_cscFalse_ctpend/seed1
# 2024-06-05 06:43:22.907062: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 06:43:22.907122: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 06:43:22.908703: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-05 06:43:22.917705: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
